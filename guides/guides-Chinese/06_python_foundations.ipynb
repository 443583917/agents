# %% [markdown]
# # Python 基础与解决 NameError
#
# ## 首先，给完全初学者的内容
#
# 这个入门教程将帮助你掌握基础知识。
#
# https://chatgpt.com/share/68063082-c2d8-8012-8d45-fa674aa1c1ed

# %% [markdown]
# ## 接下来：Python 全面教程
#
# 我把这部分交给 AI 朋友来完成，因为这些解释写得非常好，示例也很棒。将代码示例复制粘贴到新的单元格中试一试。选择你想复习的任何部分。
#
# **Python 导入（imports）：**
# https://chatgpt.com/share/672f9f31-8114-8012-be09-29ef0d0140fb
#
# **Python 函数**，包括默认参数：
# https://chatgpt.com/share/672f9f99-7060-8012-bfec-46d4cf77d672
#
# **Python 字符串**，包括切片、split/join、replace 和字面量：
# https://chatgpt.com/share/672fb526-0aa0-8012-9e00-ad1687c04518
#
# **Python f-strings**，包括数字和日期格式化：
# https://chatgpt.com/share/672fa125-0de0-8012-8e35-27918cbb481c
#
# **Python 列表、字典和集合**，包括 `get()` 方法：
# https://chatgpt.com/share/672fa225-3f04-8012-91af-f9c95287da8d
#
# **Python 文件操作**，包括模式、编码、上下文管理器、Path、glob.glob：
# https://chatgpt.com/share/673b53b2-6d5c-8012-a344-221056c2f960
#
# **Python 类：**
# https://chatgpt.com/share/672fa07a-1014-8012-b2ea-6dc679552715
#
# **Pickling Python 对象和转换为 JSON：**
# https://chatgpt.com/share/673b553e-9d0c-8012-9919-f3bb5aa23e31

# %% [markdown]
# ## 牢记这一点——理解 Python 中的 NameError
#
# 在 Python 中遇到 NameError 是相当常见的。有了基础知识后，你应该始终能够调试 NameError 并找到根本原因。
#
# 如果你在 Notebook 中工作，最常见的原因是你没有按顺序执行所有单元格，所以内核中没有定义某些内容。
#
# 如果你不确定如何修复 NameError，请查看这个[入门指南](https://chatgpt.com/share/67958312-ada0-8012-a1d3-62b3a5fcbbfc)和这个[带练习的进阶指南](https://chatgpt.com/share/67a57e0b-0194-8012-bb50-8ea76c5995b8)，通读并练习直到你充满信心。
#
# 这里有一些重复，如果你已经很有信心了可以跳过。
#
# 在此之后，NameError 将再也不会困扰你！
