# %% [markdown]
# # 命令行

# %% [markdown]
# 欢迎来到命令行使用指南。
#
# 学完本指南后，你应该能够自信地在命令行中工作，包括创建目录、移动文件等操作！

# %% [markdown]
# ## Windows PC 用户
#
# 请参阅以下教程：
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## Mac 用户
#
# 请参阅以下教程：
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# 请多加练习来建立信心。
#
# ChatGPT、Claude、Gemini、DeepSeek 等 AI 都是你的朋友！它们非常擅长详细解释各种命令行命令。这将很快变成你的第二本能。
